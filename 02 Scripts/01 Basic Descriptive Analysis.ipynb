# %% [markdown]
# Contents:
# 01 Import libraries and data
# 02 Check Output
# 03 Aggregate Key Values
# 04 Run Consistency Checks

# %% [markdown]
# 01 Import libraries and data

# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv(r'/Users/Owner/Documents/CareerFoundry/Data Immersion/Achievement 6/Mental Health Data.csv', index_col = False)

# %% [markdown]
# 02 Check Output

# %%
df.head()
# Out:
#         Entity Code  Year      Country, Year  Schizophrenia (%)  \
# 0  Afghanistan  AFG  1990  Afghanistan, 1990           0.160560
# 1  Afghanistan  AFG  1991  Afghanistan, 1991           0.160312
# 2  Afghanistan  AFG  1992  Afghanistan, 1992           0.160135
# 3  Afghanistan  AFG  1993  Afghanistan, 1993           0.160037
# 4  Afghanistan  AFG  1994  Afghanistan, 1994           0.160022
#
#    Bipolar disorder (%)  Eating disorders (%)  Anxiety disorders (%)  \
# 0              0.697779              0.101855               4.828830
# 1              0.697961              0.099313               4.829740
# 2              0.698107              0.096692               4.831108
# 3              0.698257              0.094336               4.830864
# 4              0.698469              0.092439               4.829423
#
#    Drug use disorders (%)  Depression (%)  ...  Age 50-69   Age 70+  \
# 0                1.677082        4.071831  ...   5.917752  5.202803
# ...

# %%
df.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Country, Year', 'Schizophrenia (%)',
#        'Bipolar disorder (%)', 'Eating disorders (%)', 'Anxiety disorders (%)',
#        'Drug use disorders (%)', 'Depression (%)', 'Alcohol use disorders (%)',
#        'All Ages', 'Age 10-14', 'Age 15-19', 'Age 20-24', 'Age 25-29',
#        'Age 30-34', 'Age 50-69', 'Age 70+', 'Age 15-49', 'Age Standardized',
#        'Prevalence in Males', 'Prevalence in Females', 'Population',
#        'Suicide rate (deaths per 100,000 individuals)',
#        'Depressive disorder rates (number suffering per 100,000)',
#        'Number with depression'],
#       dtype='object')

# %% [markdown]
# 03 Aggregate Key Values

# %%
pd.set_option('display.max_columns', None)

# %%
df.describe()
# Out:
#               Year  Schizophrenia (%)  Bipolar disorder (%)  \
# count  6468.000000        6468.000000           6468.000000
# mean   2003.500000           0.211644              0.719145
# std       8.078372           0.044253              0.171589
# min    1990.000000           0.146902              0.314535
# 25%    1996.750000           0.181530              0.615532
# 50%    2003.500000           0.199563              0.693134
# 75%    2010.250000           0.236365              0.835063
# max    2017.000000           0.375110              1.206597
#
#        Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# count           6468.000000            6468.000000             6468.000000
# mean               0.239998               3.989921                0.862278
# std                0.158141               1.167526                0.460679
# min                0.073908               2.023393                0.383650
# ...

# %% [markdown]
# 04 Run Consistency Checks

# %%
#check for mixed-type data

for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)
# Out:
# /var/folders/ys/d72m3mmn3kxcfr0s6frmm81w0000gn/T/ipykernel_83924/2587165438.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/ys/d72m3mmn3kxcfr0s6frmm81w0000gn/T/ipykernel_83924/2587165438.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/ys/d72m3mmn3kxcfr0s6frmm81w0000gn/T/ipykernel_83924/2587165438.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/ys/d72m3mmn3kxcfr0s6frmm81w0000gn/T/ipykernel_83924/2587165438.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %% [markdown]
# The check returned no resuts, suggesting there is no mixed-type data.

# %%
#check for missing values
df.isnull().sum()
# Out:
# Entity                                                        0
# Code                                                        980
# Year                                                          0
# Country, Year                                                 0
# Schizophrenia (%)                                             0
# Bipolar disorder (%)                                          0
# Eating disorders (%)                                          0
# Anxiety disorders (%)                                         0
# Drug use disorders (%)                                        0
# Depression (%)                                                0
# Alcohol use disorders (%)                                     0
# All Ages                                                      0
# Age 10-14                                                     0
# Age 15-19                                                     0
# Age 20-24                                                     0
# ...

# %% [markdown]
# 980 "entities" have no country code. I do not expect to use this field.

# %%
#check for duplicates
df_dups = df[df.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Year, Country, Year, Schizophrenia (%), Bipolar disorder (%), Eating disorders (%), Anxiety disorders (%), Drug use disorders (%), Depression (%), Alcohol use disorders (%), All Ages, Age 10-14, Age 15-19, Age 20-24, Age 25-29, Age 30-34, Age 50-69, Age 70+, Age 15-49, Age Standardized, Prevalence in Males, Prevalence in Females, Population, Suicide rate (deaths per 100,000 individuals), Depressive disorder rates (number suffering per 100,000), Number with depression]
# Index: []

# %% [markdown]
# As I made no changes in Jupyter, there is no need to export data.
